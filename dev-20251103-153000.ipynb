# %% [markdown]
# # Append-Only Work Log
#
# - Add items under the sections and only append new lines.
# - When a task completes, strike it out using `~~like this~~` and add a completion note.
# - Place unknowns or open questions in the RESEARCH section.
# - Use timestamp format `YYYYMMDD-HHMMSS` at the end of lines.

# %% [markdown]
# ## TODO
#
# -

# %% [markdown]
# ## COMPLETE
#
# -

# %% [markdown]
# ## RESEARCH
#
# -
